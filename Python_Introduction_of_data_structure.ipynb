# %%
#What is data structure?
#Data structure is a way of organizing and storing data so that it can be accessed and manupulated effeciently
#Data organized in an sequential way

# %%
a = "ajay"
type(a)
# Out:
# str

# %%
#Data structure - string, list, set, tuples, dictonary, array

# %%
# LIST
#list >> you can store anything in list >>
#it is a heterogeneous data >>
#heterogeneous data means >> a collection of data with high variability in data types, structures, formats or sources
#list is an ordered collection of elements that can be of any data types

# %%
num = [1, 2, 3, 4, 5]
num
# Out:
# [1, 2, 3, 4, 5]

# %%
type(num)
# Out:
# list

# %%
num[0]
# Out:
# 1

# %%
num[1]
# Out:
# 2

# %%
num[2]
# Out:
# 3

# %%
num[3]
# Out:
# 4

# %%
num[4]
# Out:
# 5

# %%
num[-1]
# Out:
# 5

# %%
num[-2]
# Out:
# 4

# %%
num[-3]
# Out:
# 3

# %%
num[-4]
# Out:
# 2

# %%
num[-5]
# Out:
# 1

# %%
num[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-2969752256.py in <cell line: 0>()
# ----> 1 num[5]
#
# IndexError: list index out of range

# %%
a = [1, 2, 3,"tomato", "baingain", "banana", True, False, (3+7J)]
a
# Out:
# [1, 2, 3, 'tomato', 'baingain', 'banana', True, False, (3+7j)]

# %%
type(a)
# Out:
# list

# %%
a
# Out:
# [1, 2, 3, 'tomato', 'baingain', 'banana', True, False, (3+7j)]

# %%
#want to add elements in this list so we can used append and the syntax is a.append
a.append("orange")
a
# Out:
# [1, 2, 3, 'tomato', 'baingain', 'banana', True, False, (3+7j), 'orange']

# %%
a.append("kajukathli")
a
# Out:
# [1,
#  2,
#  3,
#  'tomato',
#  'baingain',
#  'banana',
#  True,
#  False,
#  (3+7j),
#  'orange',
#  'kajukathli']

# %%
#want to remove the some elements/item form the list so we can used remove and the syntax is a.remove

# %%
a.remove("orange")
a
# Out:
# [1, 2, 3, 'tomato', 'baingain', 'banana', True, False, (3+7j), 'kajukathli']

# %%
#We can add list in to list
lis = [[1,2,3,], [4,5,6], [7,8,9]]

# %%
lis
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
type(lis)
# Out:
# list

# %%
#1,2,3 >> 0 & -3
#4,5,6 >> 1 & -2
#7,8,9 >> 2 & -1
lis[0]
# Out:
# [1, 2, 3]

# %%
lis[1]
# Out:
# [4, 5, 6]

# %%
lis[2]
# Out:
# [7, 8, 9]

# %%
lis[-1]
# Out:
# [7, 8, 9]

# %%
lis[-2]
# Out:
# [4, 5, 6]

# %%
lis[-3]
# Out:
# [1, 2, 3]

# %%
#so 0 is [1,2,3] and want to access 2 then the syntax is
lis[0][1]
# Out:
# 2

# %%
lis[1][1]
# Out:
# 5

# %%
#list is mutable
shopping_list = ["baingan", "apple", 2, 3.4, True]
shopping_list
# Out:
# ['baingan', 'apple', 2, 3.4, True]

# %%
shopping_list = ["baingan", "apple", 2, 3.4, True]
shopping_list[0]
# Out:
# 'baingan'

# %%
#we can also add potato insted of baingan
shopping_list = ["baingan", "apple", 2, 3.4, True]
shopping_list[0] = "potato"
shopping_list
# Out:
# ['potato', 'apple', 2, 3.4, True]

# %%
for item in shopping_list:
  print(item, end = " ")
# Out:
# potato apple 2 3.4 True

# %%
#Tuples >> Immutable
#In tuples we used () i.e small bracket
point = (2, 3)
point
# Out:
# (2, 3)

# %%
type(point)
# Out:
# tuple

# %%
#Tuple >> it is immutable data
#Not able to change data like adhar card number, atm NO. once its created
#tuple can store heterageneous data i.e any kind of data
t = (1, 2, "shweta", 2.3, True, 3+5j )
t
# Out:
# (1, 2, 'shweta', 2.3, True, (3+5j))

# %%
type(t)
# Out:
# tuple

# %%
t
# Out:
# (1, 2, 'shweta', 2.3, True, (3+5j))

# %%
emp_name = ("sanjay" , "sanjay1", "bijay", "sanjay")
emp_name
# Out:
# ('sanjay', 'sanjay1', 'bijay', 'sanjay')

# %%
type(emp_name)
# Out:
# tuple

# %%
emp_name[0]
# Out:
# 'sanjay'

# %%
emp_name[1]
# Out:
# 'sanjay1'

# %%
#consider bijay has left the office and we want to replace it to the another person rahul
emp_name[2] = "rahul"  #tuples are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2763253190.py in <cell line: 0>()
#       1 #consider bijay has left the office and we want to replace it to the another person rahul
# ----> 2 emp_name[2] = "rahul"
#
# TypeError: 'tuple' object does not support item assignment

# %%
#We can add tuple into the tupple
box1 = ("a", "b")
box2 = ("c", "d")
choc_bag = (box1, box2)

# %%
choc_bag
# Out:
# (('a', 'b'), ('c', 'd'))

# %%
type(choc_bag)
# Out:
# tuple

# %%
for box in choc_bag:
  for choc in box:
    print(choc)
# Out:
# a
# b
# c
# d

# %%
#sets >> are unordered collection of unique element
#sets are define as a curly bracket i.e {}
#it is immutable element
#we can add and remove element
s = {"red", "orange"}
type(s)
# Out:
# set

# %%
s
# Out:
# {'orange', 'red'}

# %%
s = {"red", "orange", "blue", "red", "orange"}
s
# Out:
# {'blue', 'orange', 'red'}

# %%
s = {"a", "a", 1, 1.1, 1.1, 2, 2, 2}
s
# Out:
# {1, 1.1, 2, 'a'}

# %%
s[0] #error >> no concept of indexing as sets are unordered and unique
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-243613605.py in <cell line: 0>()
# ----> 1 s[0]
#
# TypeError: 'set' object is not subscriptable

# %%
#adding element in sets
s.add("pwskills")
s
# Out:
# {1, 1.1, 2, 'a', 'pwskills'}

# %%
#removing element in the sets
s.remove("pwskills")
s
# Out:
# {1, 1.1, 2, 'a'}

# %%
grocery_list = {"apple", "banana", "banana", "egg", "egg"}
grocery_list
# Out:
# {'apple', 'banana', 'egg'}

# %%
#dictionaries >> which store the data in the form of key value pair >> we used curly bracket for that
my_dict = {}

# %%
my_dict = {}
type(my_dict)
# Out:
# dict

# %%
#In dictonary before colon it means key and after colon value of key
my_dict = {"key_cources" : "data science", "duration" : 20}
my_dict
# Out:
# {'key_cources': 'data science', 'duration': 20}

# %%
type(my_dict)
# Out:
# dict

# %%
#Use cases
phonebook = {"dad" : 1234, "mom" : 5678}
phonebook
# Out:
# {'dad': 1234, 'mom': 5678}

# %%
type(phonebook)
# Out:
# dict

# %%
#If we want to access only dad phone number then we can write this syntax
phonebook["dad"]
# Out:
# 1234

# %%
phonebook["mom"]
# Out:
# 5678

# %%
#if previous phone no. for dad was changed then it will access new no.
phonebook = {"dad" : 1234, "mom" : 5678, "dad" : 698}
phonebook["dad"]
# Out:
# 698

# %%
phonebook = {"dad" : 1234, "mom" : 5678, "dad" : 698}
phonebook["dad"]
# Out:
# 698

# %%
phonebook["mom"]
# Out:
# 5678

# %%
rest_menu = {"paneer_kofta" : 480, "chicken_handi" : 590}
rest_menu
# Out:
# {'paneer_kofta': 480, 'chicken_handi': 590}

# %%
rest_menu["paneer_kofta"]
# Out:
# 480

# %%
#if we want to modified the value paneer kofta value insated of previous value then the answer is yes
rest_menu["paneer_kofta"] = 500
rest_menu
# Out:
# {'paneer_kofta': 500, 'chicken_handi': 590}

# %%
#If we want keys then the syntax is
rest_menu.keys()
# Out:
# dict_keys(['paneer_kofta', 'chicken_handi'])

# %%
phonebook.keys()
# Out:
# dict_keys(['dad', 'mom'])

# %%
#if we want value of keys then the syntax is
rest_menu.values()
# Out:
# dict_values([500, 590])

# %%
phonebook.values()
# Out:
# dict_values([698, 5678])

# %%
#Array >> from array import array
#array is similar to list >> it is heterogeneous data >> it will strore homogeneous data

# %%
array('i', [1, 2 , 3, 4])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1392302427.py in <cell line: 0>()
# ----> 1 array('i', [1, 2 , 3, 4])
#
# NameError: name 'array' is not defined

# %%
#string >> string is immutable
s = "shweta"
type(s)
# Out:
# str

# %%
for i in s:
  print(i)
# Out:
# s
# h
# w
# e
# t
# a

# %%
s[0]
# Out:
# 's'

# %%
#instade of S we want A
s[0] = "A" #it shown an error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2507275701.py in <cell line: 0>()
#       1 #instade of S we want A
# ----> 2 s[0] = "A"
#
# TypeError: 'str' object does not support item assignment
